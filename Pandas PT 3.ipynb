# %%
import pandas as pd
import matplotlib as plt
world = pd.read_csv('/Users/bobbiewilliams/Desktop/SQL And Phyton 2025 projects/Data for Phyton Course/2018-2019 Happiness.csv')
airbnb = pd.read_csv('/Users/bobbiewilliams/Desktop/SQL And Phyton 2025 projects/Data for Phyton Course/airbnb.csv')
salaries = pd.read_csv('/Users/bobbiewilliams/Desktop/SQL And Phyton 2025 projects/Data for Phyton Course/salaries.csv')
sales = pd.read_csv('/Users/bobbiewilliams/Desktop/SQL And Phyton 2025 projects/Data for Phyton Course/web_sales.csv')
eth = pd.read_csv('/Users/bobbiewilliams/Desktop/SQL And Phyton 2025 projects/All+course+files/All course files/Python Section/Ethereum Historical Data.csv', index_col = 0)

# %%
airbnb.info() #dealing with null
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9774 entries, 0 to 9773
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Host Id                     9774 non-null   int64
#  1   Host Since                  9771 non-null   object
#  2   Name                        9774 non-null   object
#  3   Neighbourhood               9774 non-null   object
#  4   Property Type               9772 non-null   object
#  5   Review Scores Rating (bin)  8027 non-null   float64
#  6   Room Type                   9774 non-null   object
#  7   Zipcode                     9718 non-null   float64
#  8   Beds                        9745 non-null   float64
#  9   Number of Records           9773 non-null   float64
#  10  Number Of Reviews           9773 non-null   float64
#  11  Price                       9773 non-null   float64
#  12  Review Scores Rating        8026 non-null   float64
# ...

# %%
airbnb.isna().sum() # reviewing how many nulls for each columns
# Out:
# Host Id                          0
# Host Since                       3
# Name                             0
# Neighbourhood                    0
# Property Type                    2
# Review Scores Rating (bin)    1747
# Room Type                        0
# Zipcode                         56
# Beds                            29
# Number of Records                1
# Number Of Reviews                1
# Price                            1
# Review Scores Rating          1748
# dtype: int64

# %%
airbnb[airbnb['Review Scores Rating'].isna()]
airbnb_no_reviews = airbnb[airbnb['Review Scores Rating'].isna()]
airbnb_no_reviews
#showing the airbnb that is showing up without reviews
# Out:
#        Host Id  Host Since                                 Name Neighbourhood  \
# 0      5162530         NaN      1 Bedroom in Prime Williamsburg      Brooklyn
# 1     33134899         NaN      Sunny, Private room in Bushwick      Brooklyn
# 2     39608626         NaN                 Sunny Room in Harlem     Manhattan
# 3          500  26/06/2008   Gorgeous 1 BR with Private Balcony     Manhattan
# 13        2787   7/09/2008      Renovated and spacious townhome      Brooklyn
# ...        ...         ...                                  ...           ...
# 9750   3962602  24/10/2012       Beautiful East Village Bedroom     Manhattan
# 9759   3977023  25/10/2012        Cozy Room in Clinton Hill, Bk      Brooklyn
# 9764   3972617  25/10/2012         Upper east side luxury bog!!     Manhattan
# 9765   3974808  25/10/2012     Comfortable room near everything        Queens
# 9773   3983483  26/10/2012  Luxury 1BR - Times Square, Theaters     Manhattan
#
# ...

# %%
#seeing listing with reviews
airbnb_reviewed = airbnb[airbnb['Review Scores Rating'].notna()]

# %%
airbnb_reviewed
# Out:
#       Host Id  Host Since                                 Name Neighbourhood  \
# 4         500  26/06/2008             Trendy Times Square Loft     Manhattan
# 5        1039  25/07/2008   Big Greenpoint 1BD w/ Skyline View      Brooklyn
# 6        1783  12/08/2008                         Amazing Also     Manhattan
# 7        2078  15/08/2008  Colorful, quiet, & near the subway!      Brooklyn
# 8        2339  20/08/2008  East Village Cocoon: 2 Bedroom Flat     Manhattan
# ...       ...         ...                                  ...           ...
# 9768  3983140  26/10/2012    Light-Filled Prospect Height Apt.      Brooklyn
# 9769  3984304  26/10/2012   Beautiful Huge Sunny Brooklyn Loft      Brooklyn
# 9770  3981805  26/10/2012          _Boutique East Village Flat     Manhattan
# 9771  3984166  26/10/2012     East Village 2 Bedroom Apartment     Manhattan
# 9772  3982378  26/10/2012  Perfect 2BD in the heart of it all!     Manhattan
#
# ...

# %%
#drop na reviewing the null values. remove the zip codes that are nulls  
airbnb[airbnb['Zipcode'].isna()]
# Out:
#       Host Id  Host Since                                 Name Neighbourhood  \
# 133     13654  16/04/2009   Room with a view in Central Harlem     Manhattan
# 234     30990  11/08/2009    Stay in the Meatpacking District!     Manhattan
# 333     47716  22/10/2009      $45 L train/ 1 bedroom Brooklyn      Brooklyn
# 368     52677   9/11/2009            Columbus Avenue Apartment     Manhattan
# 426     58366  29/11/2009        Lincoln Center  luxury condo,     Manhattan
# 464     60944   7/12/2009  Alcove Studio West Village DrmnBldg     Manhattan
# 583     72808  23/01/2010  Coney island Entire Apt Safari Wi F      Brooklyn
# 705    101172  30/03/2010      1 BR loft 5 min walk to Time Sq     Manhattan
# 706    101172  30/03/2010  1BR w/terrace 5 min walk to Time Sq     Manhattan
# 707    101172  30/03/2010     Luxury 1BR 5 min walk to Time Sq     Manhattan
# 708    101172  30/03/2010    Modern 1 BR 5 min walk to Time Sq     Manhattan
# ...

# %%
airbnb_non_null = airbnb.dropna()

# %%
#Unique

# %%
airbnb['Neighbourhood'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Bronx', 'Staten Island'],
#       dtype=object)

# %%
airbnb['Zipcode'].nunique()
#will count how many unique zipcode adding 'n' before unique
# Out:
# 152

# %%
#Filtering data frames

# %%
airbnb
# Out:
#        Host Id  Host Since                                 Name Neighbourhood  \
# 0      5162530         NaN      1 Bedroom in Prime Williamsburg      Brooklyn
# 1     33134899         NaN      Sunny, Private room in Bushwick      Brooklyn
# 2     39608626         NaN                 Sunny Room in Harlem     Manhattan
# 3          500  26/06/2008   Gorgeous 1 BR with Private Balcony     Manhattan
# 4          500  26/06/2008             Trendy Times Square Loft     Manhattan
# ...        ...         ...                                  ...           ...
# 9769   3984304  26/10/2012   Beautiful Huge Sunny Brooklyn Loft      Brooklyn
# 9770   3981805  26/10/2012          _Boutique East Village Flat     Manhattan
# 9771   3984166  26/10/2012     East Village 2 Bedroom Apartment     Manhattan
# 9772   3982378  26/10/2012  Perfect 2BD in the heart of it all!     Manhattan
# 9773   3983483  26/10/2012  Luxury 1BR - Times Square, Theaters     Manhattan
#
# ...

# %%
airbnb[airbnb['Price'].between(100,150)]
# Out:
#       Host Id  Host Since                                 Name Neighbourhood  \
# 0     5162530         NaN      1 Bedroom in Prime Williamsburg      Brooklyn
# 5        1039  25/07/2008   Big Greenpoint 1BD w/ Skyline View      Brooklyn
# 16       2965  14/09/2008      Large Bedroom in 3-bedroom Apt.     Manhattan
# 17       3211  25/09/2008    Elegant NYC, 10mins to Manhattan!        Queens
# 18       3227  26/09/2008  Priv Apt,Garden,BBQ,A/C,BigTV,for 4     Manhattan
# ...       ...         ...                                  ...           ...
# 9756  3974045  25/10/2012       Small studio near Central Park     Manhattan
# 9757  3970236  25/10/2012      Upper West Side by Central Park     Manhattan
# 9765  3974808  25/10/2012     Comfortable room near everything        Queens
# 9767  3979151  26/10/2012   Charming 1BR@Clinton Hill,Brooklyn      Brooklyn
# 9769  3984304  26/10/2012   Beautiful Huge Sunny Brooklyn Loft      Brooklyn
#
# ...

# %%
airbnb[airbnb['Beds'].between(3,5)]
# Out:
#       Host Id  Host Since                                 Name Neighbourhood  \
# 3         500  26/06/2008   Gorgeous 1 BR with Private Balcony     Manhattan
# 4         500  26/06/2008             Trendy Times Square Loft     Manhattan
# 18       3227  26/09/2008  Priv Apt,Garden,BBQ,A/C,BigTV,for 4     Manhattan
# 19       3226  26/09/2008       Great 3 Bed Apt Tribeca / Soho     Manhattan
# 28       3867  29/10/2008    3 bedroom apartment in Chinatown!     Manhattan
# ...       ...         ...                                  ...           ...
# 9713  3958798  23/10/2012    NYC 3Bedrooms 2Bathrooms Sleeps 8     Manhattan
# 9714  3958798  23/10/2012    Nyc Penthouse 2BR Duplex Sleeps 6     Manhattan
# 9720  3955733  23/10/2012      Mint Condition 1989 Camper Home        Queens
# 9721  3955733  23/10/2012        Rustic Camper in Heart of LIC        Queens
# 9723  3951741  23/10/2012      Spacious NYC Flat in Great Area        Queens
#
# ...

# %%
airbnb[airbnb['Beds'].between(3,5)].value_counts()
# Out:
# Host Id  Host Since  Name                                 Neighbourhood  Property Type  Review Scores Rating (bin)  Room Type        Zipcode  Beds  Number of Records  Number Of Reviews  Price  Review Scores Rating
# 500      26/06/2008  Trendy Times Square Loft             Manhattan      Apartment      95.0                        Private room     10036.0  3.0   1.0                39.0               549.0  96.0                    1
# 1699273  4/02/2012   TIMES SQUARE! 5TH AVE! GREAT SPOT!!  Manhattan      Apartment      95.0                        Entire home/apt  10017.0  3.0   1.0                23.0               235.0  95.0                    1
# 1871955  6/03/2012   Centrally located, Sunny BK Escape!  Brooklyn       Apartment      90.0                        Entire home/apt  11211.0  3.0   1.0                30.0               190.0  94.0                    1
# ...

# %%
airbnb[airbnb['Price'].between(100,150)] & airbnb['Beds'].between(3,5)

# %%
potentialapartment = airbnb[(airbnb['Property Type'] == 'Apartment') & (airbnb['Neighbourhood'] == 'Brooklyn') & (airbnb['Price'] < 100)]

# %%
potentialapartment
# Out:
#        Host Id  Host Since                                 Name Neighbourhood  \
# 1     33134899         NaN      Sunny, Private room in Bushwick      Brooklyn
# 7         2078  15/08/2008  Colorful, quiet, & near the subway!      Brooklyn
# 15        2881  10/09/2008  Newly renovated historic brownstone      Brooklyn
# 23        3563  10/10/2008  16' x 11' Furnished BR with Balcony      Brooklyn
# 64        7356   3/02/2009                      BlissArtsSpace!      Brooklyn
# ...        ...         ...                                  ...           ...
# 9747   3968794  24/10/2012         Great room in nice apartment      Brooklyn
# 9748   3968794  24/10/2012     New building private budget room      Brooklyn
# 9749   3968794  24/10/2012  Private room in brand new building1      Brooklyn
# 9759   3977023  25/10/2012        Cozy Room in Clinton Hill, Bk      Brooklyn
# 9760   3977693  25/10/2012   Room: King size bed + private bath      Brooklyn
#
# ...

# %%
salaries[((salaries['job_title'] == 'Data Engineer') 
          | (salaries['job_title'] == 'Data Analyst')) 
& (salaries['salary_in_usd'] > 200000)]['job_title'].value_counts()
#job titles filtering data engineer & analyst titles how many makes over $200K
# Out:
# job_title
# Data Engineer    336
# Data Analyst      38
# Name: count, dtype: int64

# %%
#using isin method
salaries[(salaries['job_title'].isin(['Data Engineer', 'Data Analyst', 'Data Scientist']))
           
& (salaries['salary_in_usd'] > 200000)]['job_title'].value_counts()
# Out:
# job_title
# Data Scientist    377
# Data Engineer     336
# Data Analyst       38
# Name: count, dtype: int64

# %%
#isin airbnb
airbnb [airbnb['Property Type'].isin (['Bed & Breakfast', 'Loft', 'Cabin', 'Villa', 'Lighthouse'])]
# Out:
#       Host Id  Host Since                                 Name Neighbourhood  \
# 50       5926   2/01/2009   Nice  Apt Near Columbia University     Manhattan
# 59       7351   2/02/2009   2 Floor Loft room in Artist Studio      Brooklyn
# 60       7351   2/02/2009  Spacious Loft Room in Artist Studio      Brooklyn
# 61       7351   2/02/2009    Spacious room in Huge artist Loft      Brooklyn
# 92       8057  17/02/2009  HUGE MODERN LUXURY-2bed/2bath+patio     Manhattan
# ...       ...         ...                                  ...           ...
# 9752  3968209  24/10/2012                  Room in a cozy loft     Manhattan
# 9753  3968209  24/10/2012    Soho loft on grand and Crosby st.     Manhattan
# 9754  3968209  24/10/2012   Soho room in a huge loft on crosby     Manhattan
# 9758  3977494  25/10/2012   Cozy Soho Studio Loft Apt Bleecker     Manhattan
# 9769  3984304  26/10/2012   Beautiful Huge Sunny Brooklyn Loft      Brooklyn
#
# ...

# %%
#Creating a new column for data set ~
#if we add this ~ to (airbnb [airbnb['Property Type'].isin (['Bed & Breakfast', 'Loft', 'Cabin', 'Villa', 'Lighthouse'])] 
#it's going to show every thing else from what you listed

# %%
#for example 
airbnb [~airbnb['Property Type'].isin (['Bed & Breakfast', 'Loft', 'Cabin', 'Villa', 'Lighthouse'])]
# Out:
#        Host Id  Host Since                                 Name Neighbourhood  \
# 0      5162530         NaN      1 Bedroom in Prime Williamsburg      Brooklyn
# 1     33134899         NaN      Sunny, Private room in Bushwick      Brooklyn
# 2     39608626         NaN                 Sunny Room in Harlem     Manhattan
# 3          500  26/06/2008   Gorgeous 1 BR with Private Balcony     Manhattan
# 4          500  26/06/2008             Trendy Times Square Loft     Manhattan
# ...        ...         ...                                  ...           ...
# 9768   3983140  26/10/2012    Light-Filled Prospect Height Apt.      Brooklyn
# 9770   3981805  26/10/2012          _Boutique East Village Flat     Manhattan
# 9771   3984166  26/10/2012     East Village 2 Bedroom Apartment     Manhattan
# 9772   3982378  26/10/2012  Perfect 2BD in the heart of it all!     Manhattan
# 9773   3983483  26/10/2012  Luxury 1BR - Times Square, Theaters     Manhattan
#
# ...

# %%
#creating drop columns, want to add an column that says for example 'New York'

# %%
airbnb ['City'] = 'New York'

# %%
airbnb
# Out:
#        Host Id  Host Since                                 Name Neighbourhood  \
# 0      5162530         NaN      1 Bedroom in Prime Williamsburg      Brooklyn
# 1     33134899         NaN      Sunny, Private room in Bushwick      Brooklyn
# 2     39608626         NaN                 Sunny Room in Harlem     Manhattan
# 3          500  26/06/2008   Gorgeous 1 BR with Private Balcony     Manhattan
# 4          500  26/06/2008             Trendy Times Square Loft     Manhattan
# ...        ...         ...                                  ...           ...
# 9769   3984304  26/10/2012   Beautiful Huge Sunny Brooklyn Loft      Brooklyn
# 9770   3981805  26/10/2012          _Boutique East Village Flat     Manhattan
# 9771   3984166  26/10/2012     East Village 2 Bedroom Apartment     Manhattan
# 9772   3982378  26/10/2012  Perfect 2BD in the heart of it all!     Manhattan
# 9773   3983483  26/10/2012  Luxury 1BR - Times Square, Theaters     Manhattan
#
# ...

# %%
#dropping a column

# %%
airbnb.drop(labels = 'City' , axis = 1, inplace = True)

# %%
airbnb
# Out:
#        Host Id  Host Since                                 Name Neighbourhood  \
# 0      5162530         NaN      1 Bedroom in Prime Williamsburg      Brooklyn
# 1     33134899         NaN      Sunny, Private room in Bushwick      Brooklyn
# 2     39608626         NaN                 Sunny Room in Harlem     Manhattan
# 3          500  26/06/2008   Gorgeous 1 BR with Private Balcony     Manhattan
# 4          500  26/06/2008             Trendy Times Square Loft     Manhattan
# ...        ...         ...                                  ...           ...
# 9769   3984304  26/10/2012   Beautiful Huge Sunny Brooklyn Loft      Brooklyn
# 9770   3981805  26/10/2012          _Boutique East Village Flat     Manhattan
# 9771   3984166  26/10/2012     East Village 2 Bedroom Apartment     Manhattan
# 9772   3982378  26/10/2012  Perfect 2BD in the heart of it all!     Manhattan
# 9773   3983483  26/10/2012  Luxury 1BR - Times Square, Theaters     Manhattan
#
# ...

# %%
airbnb.drop(labels = 'Number of Records' , axis = 1, inplace = True)

# %%
airbnb
# Out:
#        Host Id  Host Since                                 Name Neighbourhood  \
# 0      5162530         NaN      1 Bedroom in Prime Williamsburg      Brooklyn
# 1     33134899         NaN      Sunny, Private room in Bushwick      Brooklyn
# 2     39608626         NaN                 Sunny Room in Harlem     Manhattan
# 3          500  26/06/2008   Gorgeous 1 BR with Private Balcony     Manhattan
# 4          500  26/06/2008             Trendy Times Square Loft     Manhattan
# ...        ...         ...                                  ...           ...
# 9769   3984304  26/10/2012   Beautiful Huge Sunny Brooklyn Loft      Brooklyn
# 9770   3981805  26/10/2012          _Boutique East Village Flat     Manhattan
# 9771   3984166  26/10/2012     East Village 2 Bedroom Apartment     Manhattan
# 9772   3982378  26/10/2012  Perfect 2BD in the heart of it all!     Manhattan
# 9773   3983483  26/10/2012  Luxury 1BR - Times Square, Theaters     Manhattan
#
# ...

# %%
#Generating Dynamic columns
#column dependent on another column

# %%
#example
sales
# Out:
#        ProductKey                  product product_subcategory  OrderDateKey  \
# 0             310         Road-150 Red, 62          Road Bikes      20101229
# 1             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 2             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 3             336       Road-650 Black, 62          Road Bikes      20101229
# 4             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# ...           ...                      ...                 ...           ...
# 60393         485    Fender Set - Mountain             Fenders      20140128
# 60394         225             AWC Logo Cap                Caps      20140128
# 60395         485    Fender Set - Mountain             Fenders      20140128
# 60396         486   All-Purpose Bike Stand         Bike Stands      20140128
# 60397         225             AWC Logo Cap                Caps      20140128
#
# ...

# %%
sales['Sales with Tax and Freight'] = sales['SalesAmount'] + sales['TaxAmt'] + sales['Freight']

# %%
sales
# Out:
#        ProductKey                  product product_subcategory  OrderDateKey  \
# 0             310         Road-150 Red, 62          Road Bikes      20101229
# 1             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 2             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 3             336       Road-650 Black, 62          Road Bikes      20101229
# 4             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# ...           ...                      ...                 ...           ...
# 60393         485    Fender Set - Mountain             Fenders      20140128
# 60394         225             AWC Logo Cap                Caps      20140128
# 60395         485    Fender Set - Mountain             Fenders      20140128
# 60396         486   All-Purpose Bike Stand         Bike Stands      20140128
# 60397         225             AWC Logo Cap                Caps      20140128
#
# ...

# %%
#difference between high and low (volatilty)
#example
eth['Volatility'] = eth['High'] - eth['Low']

# %%
eth
# Out:
#            Coin    Price     Open     High      Low     Vol. Change %  \
# Date
# 10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 9/02/2024   ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 8/02/2024   ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 7/02/2024   ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 6/02/2024   ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...         ...      ...      ...      ...      ...      ...      ...
# 5/01/2020   ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 4/01/2020   ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 3/01/2020   ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 2/01/2020   ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1/01/2020   ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
#             Volatility
# Date
# 10/02/2024       31.33
# 9/02/2024       103.80
# 8/02/2024        48.99
# ...

# %%
sales['Sales Type'] = sales['product_subcategory'] + ' in ' + sales['SalesTerritoryCountry']

# %%
sales
# Out:
#        ProductKey                  product product_subcategory  OrderDateKey  \
# 0             310         Road-150 Red, 62          Road Bikes      20101229
# 1             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 2             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 3             336       Road-650 Black, 62          Road Bikes      20101229
# 4             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# ...           ...                      ...                 ...           ...
# 60393         485    Fender Set - Mountain             Fenders      20140128
# 60394         225             AWC Logo Cap                Caps      20140128
# 60395         485    Fender Set - Mountain             Fenders      20140128
# 60396         486   All-Purpose Bike Stand         Bike Stands      20140128
# 60397         225             AWC Logo Cap                Caps      20140128
#
# ...
