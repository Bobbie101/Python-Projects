# %%
import pandas as pd
import matplotlib as plt
world = pd.read_csv('/Users/bobbiewilliams/Desktop/SQL And Phyton 2025 projects/Data for Phyton Course/2018-2019 Happiness.csv')
airbnb = pd.read_csv('/Users/bobbiewilliams/Desktop/SQL And Phyton 2025 projects/Data for Phyton Course/airbnb.csv')
salaries = pd.read_csv('/Users/bobbiewilliams/Desktop/SQL And Phyton 2025 projects/Data for Phyton Course/salaries.csv')
sales = pd.read_csv('/Users/bobbiewilliams/Desktop/SQL And Phyton 2025 projects/Data for Phyton Course/web_sales.csv')
eth = pd.read_csv('/Users/bobbiewilliams/Desktop/SQL And Phyton 2025 projects/All+course+files/All course files/Python Section/Ethereum Historical Data.csv'index_col=0)
# Out:
#   Cell In[84], line 7
#     eth = pd.read_csv('/Users/bobbiewilliams/Desktop/SQL And Phyton 2025 projects/All+course+files/All course files/Python Section/Ethereum Historical Data.csv'index_col=0)
#                       ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
eth
# Out:
#             Date Coin    Price     Open     High      Low     Vol. Change %
# 0     10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 1      9/02/2024  ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 2      8/02/2024  ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 3      7/02/2024  ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 4      6/02/2024  ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...          ...  ...      ...      ...      ...      ...      ...      ...
# 1497   5/01/2020  ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 1498   4/01/2020  ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 1499   3/01/2020  ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 1500   2/01/2020  ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1501   1/01/2020  ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 8 columns]

# %%
eth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1502 entries, 0 to 1501
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1502 non-null   object
#  1   Coin      1502 non-null   object
#  2   Price     1502 non-null   float64
#  3   Open      1502 non-null   float64
#  4   High      1502 non-null   float64
#  5   Low       1502 non-null   float64
#  6   Vol.      1502 non-null   object
#  7   Change %  1502 non-null   object
# dtypes: float64(4), object(4)
# memory usage: 94.0+ KB

# %%
eth.set_index('Date', inplace=True)

# %%
eth.reset_index(inplace=True)

# %%
eth
# Out:
#             Date Coin    Price     Open     High      Low     Vol. Change %
# 0     10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 1      9/02/2024  ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 2      8/02/2024  ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 3      7/02/2024  ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 4      6/02/2024  ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...          ...  ...      ...      ...      ...      ...      ...      ...
# 1497   5/01/2020  ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 1498   4/01/2020  ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 1499   3/01/2020  ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 1500   2/01/2020  ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1501   1/01/2020  ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 8 columns]

# %%
eth.sort_index()
# Out:
#             Date Coin    Price     Open     High      Low     Vol. Change %
# 0     10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 1      9/02/2024  ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 2      8/02/2024  ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 3      7/02/2024  ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 4      6/02/2024  ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...          ...  ...      ...      ...      ...      ...      ...      ...
# 1497   5/01/2020  ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 1498   4/01/2020  ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 1499   3/01/2020  ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 1500   2/01/2020  ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1501   1/01/2020  ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 8 columns]

# %%
eth.sort_values(by='Price',ascending = False) #sorting the index desending order
# Out:
#                                      Date Coin    Price     Open     High  \
# 1970-01-01 00:00:00.000000824   8/11/2021  ETH  4808.38  4612.05  4822.97
# 1970-01-01 00:00:00.000000823   9/11/2021  ETH  4731.83  4808.34  4836.69
# 1970-01-01 00:00:00.000000821  11/11/2021  ETH  4720.87  4633.98  4778.17
# 1970-01-01 00:00:00.000000820  12/11/2021  ETH  4667.31  4720.50  4807.16
# 1970-01-01 00:00:00.000000819  13/11/2021  ETH  4644.61  4665.76  4705.02
# ...                                   ...  ...      ...      ...      ...
# 1970-01-01 00:00:00.000001420  22/03/2020  ETH   122.41   132.59   136.86
# 1970-01-01 00:00:00.000001424  18/03/2020  ETH   117.77   115.95   117.91
# 1970-01-01 00:00:00.000001425  17/03/2020  ETH   116.06   111.06   120.60
# 1970-01-01 00:00:00.000001426  16/03/2020  ETH   111.02   124.35   124.38
# 1970-01-01 00:00:00.000001430  12/03/2020  ETH   107.90   194.57   195.40
#
#                                    Low     Vol. Change %
# ...

# %%
salaries.sort_values(by = ['job_title','salary_in_usd'], ascending = [True, False], inplace= True)

# %%
salaries
# Out:
#       work_year experience_level employment_type  \
# 2543       2023               SE              FT
# 3357       2023               SE              FT
# 3697       2023               SE              FT
# 3895       2023               SE              FT
# 431        2023               SE              FT
# ...         ...              ...             ...
# 1672       2020               EN              CT
# 5282       2020               EX              FT
# 3505       2020               SE              FT
# 8690       2021               SE              CT
# 3504       2021               SE              FT
#
#                             job_title  salary salary_currency  salary_in_usd  \
# 2543                     AI Architect  330000             USD         330000
# 3357                     AI Architect  330000             USD         330000
# 3697                     AI Architect  330000             USD         330000
# ...

# %%
eth.index = pd.to_datetime(eth.index)

# %%
airbnb.iloc[50]
# Out:
# Host Id                                                     5926
# Host Since                                             2/01/2009
# Name                          Nice  Apt Near Columbia University
# Neighbourhood                                          Manhattan
# Property Type                                    Bed & Breakfast
# Review Scores Rating (bin)                                  85.0
# Room Type                                           Private room
# Zipcode                                                  10031.0
# Beds                                                         1.0
# Number of Records                                            1.0
# Number Of Reviews                                           68.0
# Price                                                       55.0
# Review Scores Rating                                        86.0
# Name: 50, dtype: object

# %%
salaries
# Out:
#       work_year experience_level employment_type  \
# 0          2023               EX              FT
# 1          2023               EX              FT
# 2          2023               MI              FT
# 3          2023               MI              FT
# 4          2023               SE              FT
# ...         ...              ...             ...
# 8800       2020               SE              FT
# 8801       2021               MI              FT
# 8802       2020               EN              FT
# 8803       2020               EN              CT
# 8804       2021               SE              FT
#
#                            job_title   salary salary_currency  salary_in_usd  \
# 0              Data Science Director   212000             USD         212000
# 1              Data Science Director   190000             USD         190000
# 2     Business Intelligence Engineer    35000             GBP          43064
# ...

# %%
salaries['salary_in_usd'].value_counts().loc[90000] #locating how many people are making $90K
# Out:
# 80

# %%
world
# Out:
#      Overall rank  Year         Country or region  Score  GDP per capita  \
# 0               1  2019                   Finland  7.769           1.340
# 1               2  2019                   Denmark  7.600           1.383
# 2               3  2019                    Norway  7.554           1.488
# 3               4  2019                   Iceland  7.494           1.380
# 4               5  2019               Netherlands  7.488           1.396
# ..            ...   ...                       ...    ...             ...
# 307           152  2018                     Yemen  3.355           0.442
# 308           153  2018                  Tanzania  3.303           0.455
# 309           154  2018               South Sudan  3.254           0.337
# 310           155  2018  Central African Republic  3.083           0.024
# 311           156  2018                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# ...

# %%
world = world.set_index('Country or region').sort_values('Country or region') #setting the index to country and region to show on the left

# %%
world
# Out:
#                    Overall rank  Year  Score  GDP per capita  Social support  \
# Country or region
# Afghanistan                 154  2019  3.203           0.350           0.517
# Afghanistan                 145  2018  3.632           0.332           0.537
# Albania                     112  2018  4.586           0.916           0.817
# Albania                     107  2019  4.719           0.947           0.848
# Algeria                      84  2018  5.295           0.979           1.154
# ...                         ...   ...    ...             ...             ...
# Yemen                       152  2018  3.355           0.442           1.073
# Zambia                      138  2019  4.107           0.578           1.058
# Zambia                      125  2018  4.377           0.562           1.047
# Zimbabwe                    146  2019  3.663           0.366           1.114
# Zimbabwe                    144  2018  3.692           0.357           1.094
#
# ...

# %%
world = world.reset_index()

# %%
world = world.set_index(['Country or region', 'Year'])

# %%
world.loc['Canada', 2018]
# Out:
# index                           48.000
# Overall rank                     7.000
# Score                            7.328
# GDP per capita                   1.330
# Social support                   1.532
# Healthy life expectancy          0.896
# Freedom to make life choices     0.653
# Generosity                       0.321
# Perceptions of corruption        0.291
# Name: (Canada, 2018), dtype: float64

# %%
airbnb[10:100]
# Out:
#     Host Id  Host Since                                 Name Neighbourhood  \
# 10     2571  27/08/2008                           THE PUTNAM      Brooklyn
# 11     2758   6/09/2008     Stay at Chez Chic budget room #1     Manhattan
# 12     2758   6/09/2008     Stay at Chez Chic budget Room #2     Manhattan
# 13     2787   7/09/2008      Renovated and spacious townhome      Brooklyn
# 14     2845   9/09/2008                       Midtown Castle     Manhattan
# ..      ...         ...                                  ...           ...
# 95     8198  19/02/2009   Park Slope haven 15 mins from Soho      Brooklyn
# 96     8380  22/02/2009            River view in the Village     Manhattan
# 97     8440  23/02/2009    Beautiful studio by Prospect Park      Brooklyn
# 98     8440  23/02/2009  Luxe 1BD apartment by Prospect Park      Brooklyn
# 99     8425  23/02/2009    Charming W.Village Apt. 8/25-9/15     Manhattan
#
# ...

# %%
world = world.reset_index()

# %%
world
# Out:
#     Country or region  Year  index  Overall rank  Score  GDP per capita  \
# 0         Afghanistan  2019      0           154  3.203           0.350
# 1         Afghanistan  2018      1           145  3.632           0.332
# 2             Albania  2018      2           112  4.586           0.916
# 3             Albania  2019      3           107  4.719           0.947
# 4             Algeria  2018      4            84  5.295           0.979
# ..                ...   ...    ...           ...    ...             ...
# 307             Yemen  2018    307           152  3.355           0.442
# 308            Zambia  2019    308           138  4.107           0.578
# 309            Zambia  2018    309           125  4.377           0.562
# 310          Zimbabwe  2019    310           146  3.663           0.366
# 311          Zimbabwe  2018    311           144  3.692           0.357
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# ...

# %%
world.set_index('Overall rank').sort_index().loc[1:10]
# Out:
#              Country or region  Year  index  Score  GDP per capita  \
# Overall rank
# 1                      Finland  2018     87  7.632           1.305
# 1                      Finland  2019     88  7.769           1.340
# 2                      Denmark  2019     73  7.600           1.383
# 2                       Norway  2018    211  7.594           1.456
# 3                      Denmark  2018     74  7.555           1.351
# 3                       Norway  2019    210  7.554           1.488
# 4                      Iceland  2019    114  7.494           1.380
# 4                      Iceland  2018    115  7.495           1.343
# 5                  Netherlands  2019    198  7.488           1.396
# 5                  Switzerland  2018    266  7.487           1.420
# 6                  Switzerland  2019    267  7.480           1.452
# 6                  Netherlands  2018    197  7.441           1.361
# 7                       Canada  2018     48  7.328           1.330
# ...

# %%
top_10_jobs = pd.DataFrame (salaries['job_title'].value_counts()).head(10)

# %%
top_10_jobs.sort_values (by = 'count').plot(kind= 'barh') # creating a graph using horizontal bar graph
# Out:
# <Axes: ylabel='job_title'>

# %%
salaries
